# %%
# %matplotlib inline

# %%
from sandbox import think_pmf

think_pmf.main()
# Out:
# [2, 0, 14, 1, 2, 1, 5, 3, 2, 11] [1, 4, 3, 3, 2, 4, 5, 5, 2, 4, 4, 4, 3]
# Greece
# 0.1843137254901961

# %%
from sandbox import ftp_test

ftp_test.main()
# Out:
# drwxr-x---   11 spitoglo   99               4096 Sep  3 02:55 .
# drwx--x--x   33 spitoglo   spitoglo         4096 Sep  2 03:23 ..
# drwxr-xr-x    4 spitoglo   spitoglo         4096 Sep  4 07:03 .well-known
# drwxr-xr-x    2 spitoglo   spitoglo         4096 Sep  2 03:09 cgi-bin
# drwxr-xr-x   28 spitoglo   spitoglo         4096 Sep  5 05:39 england
# -rw-r--r--    1 spitoglo   spitoglo         4286 Sep  5 05:30 favicon.ico
# drwxr-xr-x   25 spitoglo   spitoglo         4096 Sep  5 05:37 france
# drwxr-xr-x   24 spitoglo   spitoglo         4096 Sep  5 05:42 germany
# drwxr-xr-x   21 spitoglo   spitoglo         4096 Sep  5 05:30 greece
# -rw-r--r--    1 spitoglo   spitoglo         1148 Sep  5 05:30 highlight.css
# -rw-r--r--    1 spitoglo   spitoglo         9313 Sep  5 05:30 highlight.js
# -rw-r--r--    1 spitoglo   spitoglo         1689 Sep  5 05:30 index.html
# drwxr-xr-x   27 spitoglo   spitoglo         4096 Sep  5 05:34 italy
# ...
