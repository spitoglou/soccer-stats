# %%
from lib.championships import load_greece, load_england, load_italy, team_stats
from lib import period_stats, create_team_df_dict
import pandas as pd
pd.set_option('display.max_rows', 500)

# %%
df = load_greece()

# %%
df.tail()

# %%
team_dfs = create_team_df_dict(df)
team_dfs['PAOK']

# %%
england = load_england()
eng_team_dfs = create_team_df_dict(england)
eng_team_dfs['Fulham']

# %%
team_stats(eng_team_dfs).iloc[:,8:]

# %%
team_stats(team_dfs).iloc[:,8:]
